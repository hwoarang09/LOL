# %%
import requests
from pandas.io.json import json_normalize
import requests
import pandas as pd
import numpy as np
import time
from pandas.io.json import json_normalize
import requests
import pandas as pd
import numpy as np
import time
import pandas as pd
import pickle
import champ_key_trans

df_id_list=pd.read_csv(r"C:\Users\hwoar\LOL\list_id.csv")
api_key='RGAPI-862490fb-0ebd-4b90-b7b7-7eadec9c2300'

list_gameId = []
for k in range(0,10):
    list_imsi =[]

    try:
        summoner_name=df_id_list.iloc[k][1]
        sohwan = "https://kr.api.riotgames.com/lol/summoner/v4/summoners/by-name/" +summoner_name+'?api_key=' + api_key
        R_sohwan = requests.get(sohwan)
        print("encrypted accountID : ", R_sohwan.json()['accountId'])
        en_summoner_id=R_sohwan.json()['id']
        sohwan2=('https://kr.api.riotgames.com/lol/league/v4/entries/by-summoner/'+en_summoner_id+ '?api_key='+ api_key)
        R_sohwan2 = requests.get(sohwan2)
        print("ID : ", R_sohwan2.json()[0]['summonerName'])
        print("wins : ", R_sohwan2.json()[0]['wins'])
        print("losses : ", R_sohwan2.json()[0]['losses'])
        print("Games play  : ", R_sohwan2.json()[0]['wins'] + R_sohwan2.json()[0]['losses'], '\n')
        totalGames=R_sohwan2.json()[0]['wins'] + R_sohwan2.json()[0]['losses']
        
        
        list_imsi.append(R_sohwan2.json()[0]['summonerName'])
        list_imsi.append(gameId_get(R_sohwan.json()['accountId']))
        
        

    except:
        while (R_sohwan.status_code == 429)or (R_sohwan2.status_code == 429):
            time.sleep(5)
            summoner_name=df_id_list.iloc[k][1]
            sohwan = "https://kr.api.riotgames.com/lol/summoner/v4/summoners/by-name/" +summoner_name+'?api_key=' + api_key
            R_sohwan = requests.get(sohwan)
            print("encrypted accountID : ", R_sohwan.json()['accountId'])
            en_summoner_id=R_sohwan.json()['id']
            sohwan2=('https://kr.api.riotgames.com/lol/league/v4/entries/by-summoner/'+en_summoner_id+ '?api_key='+ api_key)
            R_sohwan2 = requests.get(sohwan2)
            print("ID : ", R_sohwan2.json()[0]['summonerName'])
            print("wins : ", R_sohwan2.json()[0]['wins'])
            print("losses : ", R_sohwan2.json()[0]['losses'])
            print("Games play  : ", R_sohwan2.json()[0]['wins'] + R_sohwan2.json()[0]['losses'], '\n')
            totalGames=R_sohwan2.json()[0]['wins'] + R_sohwan2.json()[0]['losses']


            list_imsi.append(R_sohwan2.json()[0]['summonerName'])
            list_imsi.append(gameId_get(R_sohwan.json()['accountId']))
        print("No Summoner : ", summoner_name, "\n")
        pass
    list_gameId.append(list_imsi)
    list_imsi=[]
# Out:
# encrypted accountID :  MDqRi9a2d2VnDv4HvGfy35UjjTFbwAPbP7upqLEMNFxH6GxFykJOUMJq
# ID :  StarSpring
# wins :  128
# losses :  116
# Games play  :  244
#
# No Summoner :  StarSpring
#
# encrypted accountID :  m4wZBLbseCsr9cXCHQxqh9ev1-7pAvqR1rKmn6C9sQk
# ID :  THE ALL NEW LIFE
# wins :  229
# losses :  205
# Games play  :  434
#
# No Summoner :  THE ALL NEW LIFE
#
# encrypted accountID :  guLj3E7IBlP3bX1CVR6kw9hAIp31IVpPe0247en5Q5PiWJl1NRxhIRq9
# ID :  나랑해보자는건가
# wins :  101
# losses :  42
# Games play  :  143
#
# No Summoner :  나랑해보자는건가
#
# encrypted accountID :  4x4xHJIZSQOOsThONJ6C0GbPwSA0M1C-lMGtMd1DGd363tKrypGQ5mJs
# ID :  ruozhiyaoyao
# wins :  166
# losses :  108
# Games play  :  274
#
# No Summoner :  ruozhiyaoyao
#
# No Summoner :  Astralis2
#
# encrypted accountID :  DEfDFdGFoxDP9ahUHPZZ2CCGCU-SSKdgw-mXq8bYxcQ9bJ4x6Xg_YhpY
# ID :  유시온재키와이
# wins :  250
# losses :  192
# Games play  :  442
#
# No Summoner :  유시온재키와이
#
# encrypted accountID :  bYj_C_WyWYpR_e1agbCUy-cSJOs_2n38Dx-t2jCo18lOEq4
# ID :  김성은겨드랑이털
# wins :  106
# losses :  91
# Games play  :  197
#
# No Summoner :  김성은겨드랑이털
#
# encrypted accountID :  iQacHGTmxyTOMhFIu19hxL2WmiKqhQ3NjCv5GY-H7NWG8CYMmTSMNFSg
# ID :  Blesssing
# wins :  657
# losses :  625
# Games play  :  1282
#
# No Summoner :  Blesssing
#
# encrypted accountID :  OnRY88Q3D6wtZTn0lMCca1d-10R1AVRHRUCOk2JxPAhuAtm2Ma7oy-jd
# ID :  dopopo
# wins :  84
# losses :  29
# Games play  :  113
#
# No Summoner :  dopopo
#
# encrypted accountID :  SIul5vjZlNlUCYHpkYKTF77w_ledxA8L7vql8XrmuK2-7BxdyvQ581Vt
# ID :  중양절9
# wins :  273
# losses :  268
# Games play  :  541
#
# No Summoner :  중양절9

# %%
list_gameId
# Out:
# [['StarSpring'],
#  ['THE ALL NEW LIFE'],
#  ['나랑해보자는건가'],
#  ['ruozhiyaoyao'],
#  [],
#  ['유시온재키와이'],
#  ['김성은겨드랑이털'],
#  ['Blesssing'],
#  ['dopopo'],
#  ['중양절9']]

# %%
def gameId_get(en_id,key):
    gameId_list = []


    aa=int((totalGames)/100)
    k=0
    while k<=aa:
        #print(k*100,'부터 ', (k+1)*100, '까지')
 
        endindex=(k+1)*100
        startindex=k*100
        matchlist = ('https://kr.api.riotgames.com/lol/match/v4/matchlists/by-account/'+ en_id + 
                     '?champion='+ckt(key)+'&queue=420&endIndex='+str(endindex)+'&beginIndex='+str(startindex)+
                     '&api_key='+api_key)
        R_matchlist = requests.get(matchlist)

        #print(startindex, endindex)
        try:
            for a in range(0, totalGames+1-startindex):
                #gameId_list.append(R_matchlist.json()['matches'][a]['gameId'])
                if (R_matchlist.json()['matches'][a]['queue']==420):
                    gameId_list.append(R_matchlist.json()['matches'][a]['gameId'])
                    #print(R_matchlist.json()['matches'][a]['queue'], R_matchlist.json()['matches'][a]['gameId'])




                while R_matchlist.status_code == 429:
                    time.sleep(5)
                    print('429error......쉬엇다간다1')
                    #gameId_list.append(R_matchlist.json()['matches'][a]['gameId'])
                    if (R_matchlist.json()['matches'][a]['queue']==420):
                        gameId_list.append(R_matchlist.json()['matches'][a]['gameId'])


        except:
            pass
        k+=1




    print(len(gameId_list), "  :  ", totalGames)        
    return gameId_list

# %%
def id_timeline_SUM(summoner):
    list_id_timeline_SUM = []
    #for i in range(0, len(summoner):
    for i in range(0, 20):
        gameId_one=summoner[i]
        list_id_timeline={}
        list_id_timeline['gameId']=gameId_one
        try:

            match_Id='https://kr.api.riotgames.com/lol/match/v4/matches/' +str(gameId_one)+'?api_key=RGAPI-862490fb-0ebd-4b90-b7b7-7eadec9c2300'
            R_match_Id=requests.get(match_Id)
            list_id_timeline['match_Id'] = R_match_Id.json()
        except:
            while R_match_Id.status_code == 429:
                time.sleep(5)
                print('429error......쉬엇다간다1')
                gameId_one=list_gameId[0][1][i]
                match_Id='https://kr.api.riotgames.com/lol/match/v4/matches/' +str(gameId_one)+'?api_key=RGAPI-862490fb-0ebd-4b90-b7b7-7eadec9c2300'
                R_match_Id=requests.get(match_Id)
            list_id_timeline['match_Id'] = R_match_Id.json()



        try:
            match_timeline='https://kr.api.riotgames.com/lol/match/v4/timelines/by-match/' +str(gameId_one)+'?api_key=RGAPI-862490fb-0ebd-4b90-b7b7-7eadec9c2300'
            R_match_timeline=requests.get(match_timeline)
            list_id_timeline['match_timeline']=R_match_timeline.json()
        except:
            while R_match_timeline.status_code == 429:
                time.sleep(5)
                print('429error......쉬엇다간다1')
                match_timeline='https://kr.api.riotgames.com/lol/match/v4/timelines/by-match/' +str(gameId_one)+'?api_key=RGAPI-862490fb-0ebd-4b90-b7b7-7eadec9c2300'
                R_match_timeline=requests.get(match_timeline)
            list_id_timeline['match_timeline']=R_match_timeline.json()


        list_id_timeline_SUM.append(list_id_timeline)
    return list_id_timeline_SUM

# %%
id_timeline_SUM(list_gameId[0][1])

# %%
en_id

# %%
len(id_timeline_SUM(list_gameId[0][1]))
